# %%
import numpy as np
import pandas as pd
df = pd.read_csv("final_csv.csv")
df1 = df.set_index('topic')
gk = df.groupby(['topic'])
df1
# Out:
#                                                                link  \
# topic
# education         https://skillsion.com/protractor-testing-training
# 0-2021            https://skillsion.com/protractor-testing-training
# 15-puzzle                   https://en.wikipedia.org/wiki/15_puzzle
# 15-puzzle               https://www.youtube.com/watch?v=YI1WqYKHi78
# 15-puzzle         https://www.jstor.org/stable/2369492?seq=1#met...
# ...                                                             ...
# Coordinate plane  https://www.khanacademy.org/math/basic-geo/bas...
# Coordinate plane  https://www.mathsisfun.com/data/cartesian-coor...
# Counting          https://betterexplained.com/articles/learning-...
# Counting             https://en.wikipedia.org/wiki/Off-by-one_error
# Nihilism          https://thereader.mitpress.mit.edu/what-nihili...
#
#                                                                name
# topic
# ...

# %%
df
# Out:
#                                                     link  \
# 0      https://skillsion.com/protractor-testing-training
# 1      https://skillsion.com/protractor-testing-training
# 2                https://en.wikipedia.org/wiki/15_puzzle
# 3            https://www.youtube.com/watch?v=YI1WqYKHi78
# 4      https://www.jstor.org/stable/2369492?seq=1#met...
# ...                                                  ...
# 27596  https://www.khanacademy.org/math/basic-geo/bas...
# 27597  https://www.mathsisfun.com/data/cartesian-coor...
# 27598  https://betterexplained.com/articles/learning-...
# 27599     https://en.wikipedia.org/wiki/Off-by-one_error
# 27600  https://thereader.mitpress.mit.edu/what-nihili...
#
#                                                     name             topic
# 0      https://skillsion.com/protractor-testing-training         education
# 1      https://skillsion.com/protractor-testing-training            0-2021
# ...

# %%
gk.head()
# Out:
#                                                     link  \
# 0      https://skillsion.com/protractor-testing-training
# 1      https://skillsion.com/protractor-testing-training
# 2                https://en.wikipedia.org/wiki/15_puzzle
# 3            https://www.youtube.com/watch?v=YI1WqYKHi78
# 4      https://www.jstor.org/stable/2369492?seq=1#met...
# ...                                                  ...
# 27596  https://www.khanacademy.org/math/basic-geo/bas...
# 27597  https://www.mathsisfun.com/data/cartesian-coor...
# 27598  https://betterexplained.com/articles/learning-...
# 27599     https://en.wikipedia.org/wiki/Off-by-one_error
# 27600  https://thereader.mitpress.mit.edu/what-nihili...
#
#                                                     name             topic
# 0      https://skillsion.com/protractor-testing-training         education
# 1      https://skillsion.com/protractor-testing-training            0-2021
# ...

# %%
x = df.loc[:,2]== "education"
x
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27596    False
# 27597    False
# 27598    False
# 27599    False
# 27600    False
# Name: 2, Length: 27601, dtype: bool
